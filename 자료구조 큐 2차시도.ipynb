# %%
class Node:
    #연결리스트를 구현하기 위한 노드 정의
    def __init__(self, data):
        self.data = data
        self.link = None
        
class Queue:
    #큐에서 사용되는 연산
    def __init__(self):
        self.front = None
        self.rear = None
        self.size = 0
    
    def enqueue(self, item): #삽입
        newNode = Node(item)
        if (self.rear == None): #큐가 공백일 경우
            self.rear = newNode
            self.front = newNode
        else:
            self.rear.link = newNode
            self.rear = newNode
        self.size += 1
            
    def dequeue(self): # 삭제하고 반환
        global item
        if (self.front == None):
            item = 'Queue is Empty' #underflow check
        else:
            #oldNode = self.front
            item = self.front.data
            self.front = self.front.link
            if (self.front == None): #삭제로 인해 큐가 공백이 된 경우
                self.rear = None
        self.size -= 1
        return item
    
    def delete(self): # 삭제
        if (self.front == None):
            print('Queue is Empty') #underflow check
        else:
            #oldNode = self.front
            self.front = self.front.link
            if (self.front == None): #삭제로 인해 큐가 공백이 된 경우
                self.rear = None
        self.size -= 1   
        
    def peek(self): #큐의 front 원소를 검색
        if (self.front == None):
            print('Queue is Empty')
        else:
            print(self.front.data)

    def printq(self): #큐의 모든 리스트를 보여주기 위한 함수
        oldNode = self.front
        if (self.front == None):
            print('Queue is Empty')
        else:
            num = self.size
            for i in range(num-1):
                print(self.front.data, end = '->')
                self.front = self.front.link
            print(self.front.data)
        self.front = oldNode
            
queue = Queue()

while True:
    print('-------------------------------------')
    select = input('이 중 수행할 활동을 선택하시오.\n1. 대기자 명단 보기\n2. 대기자 추가하기\n3. 대기자 호명하기\n4. 대기인원수\n5. 대기자 순서에서 삭제\n6. 그만하기\n')
    print('-------------------------------------')
    if select == '1':
        print('현재 남은 대기자는 : ') ; print(queue.printq())
    elif select == '2':
        while True: #대기자 명단 받기
            item = input('대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) : ')
            if item == '':
                break
            else:
                queue.enqueue(item)
    elif select == '3':
        if item == 'Queue is Empty':
            print('Queue is Empty')
        else:
            print(queue.dequeue(), '님 순서입니다..')
    elif select == '4':
        print(queue.size,'명')
    elif select == '5':
        queue.delete()
        print('대기자가 삭제되었습니다.')
    elif select == '6':
        print('end')
        break
    else:
        print('목록을 다시 확인해주세요.')
# Out:
# -------------------------------------
# 이 중 수행할 활동을 선택하시오.
# 1. 대기자 명단 보기
# 2. 대기자 추가하기
# 3. 대기자 호명하기
# 4. 대기인원수
# 5. 대기자 순서에서 삭제
# 6. 그만하기
# 1
# -------------------------------------
# 현재 남은 대기자는 :
# Queue is Empty
# None
# -------------------------------------
# 이 중 수행할 활동을 선택하시오.
# 1. 대기자 명단 보기
# 2. 대기자 추가하기
# 3. 대기자 호명하기
# 4. 대기인원수
# 5. 대기자 순서에서 삭제
# 6. 그만하기
# 2
# -------------------------------------
# 대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) : 곽내원
# 대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) : 송명재
# 대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) :
# -------------------------------------
# 이 중 수행할 활동을 선택하시오.
# 1. 대기자 명단 보기
# 2. 대기자 추가하기
# 3. 대기자 호명하기
# 4. 대기인원수
# 5. 대기자 순서에서 삭제
# 6. 그만하기
# 2
# -------------------------------------
# 대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) : 김정희
# 대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) :
# -------------------------------------
# 이 중 수행할 활동을 선택하시오.
# 1. 대기자 명단 보기
# 2. 대기자 추가하기
# 3. 대기자 호명하기
# 4. 대기인원수
# 5. 대기자 순서에서 삭제
# 6. 그만하기
# 3
# -------------------------------------
# 곽내원 님 순서입니다..
# ...

# %%
class Node:
    #연결리스트를 구현하기 위한 노드 정의
    def __init__(self, data):
        self.data = data
        self.link = None
        
class Queue:
    #큐에서 사용되는 연산
    def __init__(self):
        self.front = None
        self.rear = None
        self.size = 0
    
    def enqueue(self, item): #삽입
        newNode = Node(item)
        if (self.rear == None): #큐가 공백일 경우
            self.rear = newNode
            self.front = newNode
        else:
            self.rear.link = newNode
            self.rear = newNode
        self.size += 1
            
    def dequeue(self): # 삭제하고 반환
        if (self.front == None):
            print('Queue is Empty') #underflow check
        else:
            #oldNode = self.front
            item = self.front.data
            self.front = self.front.link
            if (self.front == None): #삭제로 인해 큐가 공백이 된 경우
                self.rear = None
        self.size -= 1
        return item
    
    def delete(self): # 삭제
        if (self.front == None):
            print('Queue is Empty') #underflow check
        else:
            #oldNode = self.front
            self.front = self.front.link
            if (self.front == None): #삭제로 인해 큐가 공백이 된 경우
                self.rear = None
        self.size -= 1   
        
    def peek(self): #큐의 front 원소를 검색
        if (self.front == None):
            print('Queue is Empty')
        else:
            print(self.front.data)

    def printq(self): #큐의 모든 리스트를 보여주기 위한 함수
        oldNode = self.front
        if (self.front == None):
            print('Queue is Empty')
        else:
            num = self.size
            for i in range(num-1):
                print(self.front.data, end = '->')
                self.front = self.front.link
            print(self.front.data)
        self.front = oldNode
            
queue = Queue()

while True:
    select = int(input('이 중 수행할 활동을 선택하시오.\n1. 대기자 명단 보기\n2. 대기자 추가하기\n3. 대기자 호명하기\n4. 대기인원수\n5. 대기자 순서에서 삭제\n6. 그만하기\n'))
    if select == 1:
        print('현재 남은 대기자는 : ') ; print(queue.printq())
    elif select == 2:
        while True: #대기자 명단 받기
            item = input('대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) : ')
            if item == '':
                break
            else:
                queue.enqueue(item)
    elif select == 3:
        print(queue.dequeue(), '님 순서입니다..')
    elif select == 4:
        print(queue.size,'명')
    elif select == 5:
        queue.delete()
        print('대기자가 삭제되었습니다.')
    elif select == 6:
        print('end')
        break
    else:
        print('목록을 다시 확인해주세요.')

# %%
    def printq(self): #큐의 모든 리스트를 보여주기 위한 함수
        if (self.front == None):
            print('Queue is Empty')
        else:
            num = self.size
            for i in range(num-1):
                print(self.front.data, end = '->')
                self.front = self.front.link
            print(self.front.data)
            

    def printq(self): #큐의 모든 리스트를 보여주기 위한 함수
        if (self.front == None):
            print('Queue is Empty')
        else:
            num = self.size
            while (self.front != None):
                print(self.front.data, end = '->')
                self.front = self.front.link

# %%
queue = Queue()

while True: #대기자 명단 받기
    item = input('대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) : ')
    if item == '':
        break
    else:
        queue.enqueue(item)


print(queue.printq()) #대기자 명단 보기
#print(queue.front.data)
#print(queue.rear.data)

# %%
    def printq(self): #큐의 모든 리스트를 보여주기 위한 함수
        if (self.front == None):
            print('Queue is Empty')
        else:
            node1 = self.front.link
            node2 = self.front
            print(node2, end = '->')
            while (node1 != node2):
                print(node1, end = '->')
                node1 = node1.link
# Out:
# 대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) : a
# 대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) : b
# 대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) : c
# 대기자 이름을 입력하시오.(끝내려면 엔터를 눌러주세요.) :
# <__main__.Node object at 0x00000192BF0AC5C0>-><__main__.Node object at 0x00000192BF0A1FD0>-><__main__.Node object at 0x00000192BF087BA8>->None->
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-768cc53154fc> in <module>()
#      66         queue.enqueue(item)
#      67
# ---> 68 print(queue.printq())
#      69 print(queue.front.data)
#      70 print(queue.rear.data)
#
# <ipython-input-26-768cc53154fc> in printq(self)
#      55             while (node1 != node2):
#      56                 print(node1, end = '->')
# ---> 57                 node1 = node1.link
#      58
#      59 queue = Queue()
#
# AttributeError: 'NoneType' object has no attribute 'link'
